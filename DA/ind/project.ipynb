# %%
import csv
import pandas as pd
import numpy as np
def read_data(filename):
    data = []
    with open(filename, newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=';')
        header = next(reader)
        for row in reader:
            record = {
                
                
            }
            data.append(record)
    return data
csv_file_path = "BankChurners.csv"
data = read_data(csv_file_path)
df = pd.DataFrame(data)
selected_columns = []
df[selected_columns] = df[selected_columns].replace('', np.nan).astype(float)
describe_stats = df[selected_columns].describe()
mean_values = df[selected_columns].mean()
median_values = df[selected_columns].median()
variance_values = df[selected_columns].var()
correlation_matrix = df[selected_columns].corr()
print("Descriptive Statistics:")
print(describe_stats)
print("\nMean Values:")
print(mean_values)
print("\nMedian Values:")
print(median_values)
print("\nVariance Values:")
print(variance_values)
print("\nCorrelation Matrix:")
print(correlation_matrix)
# Out:
# Descriptive Statistics:
#             CO(GT)     C6H6(GT)      NOx(GT)      NO2(GT)            T  \
# count  9357.000000  9357.000000  9357.000000  9357.000000  9357.000000
# mean    -34.207524     1.865683   168.616971    58.148873     9.778305
# std      77.657170    41.380206   257.433866   126.940455    43.203623
# min    -200.000000  -200.000000  -200.000000  -200.000000  -200.000000
# 25%       0.600000     4.000000    50.000000    53.000000    10.900000
# 50%       1.500000     7.900000   141.000000    96.000000    17.200000
# 75%       2.600000    13.600000   284.000000   133.000000    24.100000
# max      11.900000    63.700000  1479.000000   340.000000    44.600000
#
#                 RH           AH
# count  9357.000000  9357.000000
# mean     39.485380    -6.837604
# std      51.216145    38.976670
# min    -200.000000  -200.000000
# 25%      34.100000     0.692300
# 50%      48.600000     0.976800
# 75%      61.900000     1.296200
# max      88.700000     2.231000
#
# Mean Values:
# CO(GT)      -34.207524
# C6H6(GT)      1.865683
# NOx(GT)     168.616971
# NO2(GT)      58.148873
# T             9.778305
# RH           39.485380
# AH           -6.837604
# dtype: float64
#
# Median Values:
# CO(GT)        1.5000
# C6H6(GT)      7.9000
# NOx(GT)     141.0000
# NO2(GT)      96.0000
# T            17.2000
# RH           48.6000
# AH            0.9768
# dtype: float64
#
# Variance Values:
# CO(GT)       6030.636106
# C6H6(GT)     1712.321485
# NOx(GT)     66272.195514
# NO2(GT)     16113.879181
# T            1866.553046
# RH           2623.093506
# AH           1519.180817
# dtype: float64
#
# Correlation Matrix:
#             CO(GT)  C6H6(GT)   NOx(GT)   NO2(GT)         T        RH        AH
# CO(GT)    1.000000 -0.031378  0.526451  0.671127 -0.068939 -0.048227 -0.045892
# C6H6(GT) -0.031378  1.000000 -0.001174 -0.010992  0.971375  0.925062  0.984555
# NOx(GT)   0.526451 -0.001174  1.000000  0.817139 -0.138452 -0.053009 -0.095847
# NO2(GT)   0.671127 -0.010992  0.817139  1.000000 -0.084104 -0.081305 -0.060440
# T        -0.068939  0.971375 -0.138452 -0.084104  1.000000  0.885911  0.981001
# RH       -0.048227  0.925062 -0.053009 -0.081305  0.885911  1.000000  0.943995
# AH       -0.045892  0.984555 -0.095847 -0.060440  0.981001  0.943995  1.000000
