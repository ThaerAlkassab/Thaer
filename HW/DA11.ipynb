# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
import seaborn as sns
# %matplotlib inline

# %%
anscombe = sns.load_dataset('anscombe')

# %%
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
anscombe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
# dataset    44 non-null object
# x          44 non-null float64
# y          44 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 916.0+ bytes

# %%
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
anscombe.groupby('dataset').mean()
# Out:
#            x         y
# dataset
# I        9.0  7.500909
# II       9.0  7.500909
# III      9.0  7.500000
# IV       9.0  7.500909

# %%
anscombe.groupby('dataset').std()
# Out:
#                 x         y
# dataset
# I        3.316625  2.031568
# II       3.316625  2.031657
# III      3.316625  2.030424
# IV       3.316625  2.030579

# %%
anscombe.groupby('dataset').corr()
# Out:
#                   x         y
# dataset
# I       x  1.000000  0.816421
#         y  0.816421  1.000000
# II      x  1.000000  0.816237
#         y  0.816237  1.000000
# III     x  1.000000  0.816287
#         y  0.816287  1.000000
# IV      x  1.000000  0.816521
#         y  0.816521  1.000000

# %%
plt.plot(list(anscombe.groupby('dataset').x), list(anscombe.groupby('dataset').y))
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-27-506859f54510> in <module>()
# ----> 1 plt.plot(list(anscombe.groupby('dataset').x), list(anscombe.groupby('dataset').y))
#
# c:\ProgramData\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# c:\ProgramData\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# c:\ProgramData\Anaconda2\lib\site-packages\matplotlib\axes\_axes.pyc in plot(self, *args, **kwargs)
# ...

# %%
list(anscombe.groupby('dataset').x)
# Out:
# [('I', 0     10.0
#   1      8.0
#   2     13.0
#   3      9.0
#   4     11.0
#   5     14.0
#   6      6.0
#   7      4.0
#   8     12.0
#   9      7.0
#   10     5.0
#   Name: x, dtype: float64), ('II', 11    10.0
#   12     8.0
#   13    13.0
#   14     9.0
#   15    11.0
#   16    14.0
#   17     6.0
#   18     4.0
#   19    12.0
#   20     7.0
#   21     5.0
#   Name: x, dtype: float64), ('III', 22    10.0
#   23     8.0
#   24    13.0
#   25     9.0
#   26    11.0
#   27    14.0
#   28     6.0
#   29     4.0
#   30    12.0
#   31     7.0
#   32     5.0
#   Name: x, dtype: float64), ('IV', 33     8.0
#   34     8.0
#   35     8.0
#   36     8.0
#   37     8.0
#   38     8.0
#   39     8.0
#   40    19.0
#   41     8.0
#   42     8.0
#   43     8.0
#   Name: x, dtype: float64)]

# %%
plt.figure(figsize = (10,8))
i=0
for item in anscombe['dataset'].unique():

# %%
fig, ax = plt.subplots(1,2)
x = [1,2,3,4]
y = [1,4,9,16]
ax[0].plot(x,y)
plt.show()
