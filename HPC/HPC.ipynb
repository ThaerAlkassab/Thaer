# %%
import random

lower = int(input("Enter Lower bound: "))

upper = int(input("Enter Upper bound: "))

count = 0
num = '10'
while num != 'y':
    x = random.randint(lower, upper)
    count += 1
    print (f'\nmy guess is {x} \t')
    num = input("is my guess right?\n write y for yes and b for bigger number\n and s for smaller number\n")
    if num == 's':
        upper = x
        print("so I should guess a smaller number \n ")
    elif num == 'b':
        lower = x+1
        print("so I should guess a bigger number \n ")
print(f'I did it, I guessed the number in {count} tries')
# Out:
# Enter Lower bound: 0
# Enter Upper bound: 100
#
# my guess is 12
# is my guess right?
#  write y for yes and b for bigger number
#  and s for smaller number
# b
# so I should guess a bigger number
#
#
# my guess is 77
# is my guess right?
#  write y for yes and b for bigger number
#  and s for smaller number
# s
# so I should guess a smaller number
#
#
# my guess is 63
# is my guess right?
#  write y for yes and b for bigger number
#  and s for smaller number
# s
# so I should guess a smaller number
#
#
# my guess is 22
# is my guess right?
#  write y for yes and b for bigger number
#  and s for smaller number
# b
# so I should guess a bigger number
#
#
# my guess is 50
# is my guess right?
#  write y for yes and b for bigger number
#  and s for smaller number
# s
# so I should guess a smaller number
#
#
# my guess is 28
# is my guess right?
#  write y for yes and b for bigger number
#  and s for smaller number
# s
# so I should guess a smaller number
#
#
# my guess is 27
# ...
